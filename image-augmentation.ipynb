# %%
import numpy as np
from skimage.io import imread, imsave
import matplotlib.pyplot as plt
from skimage import transform
from skimage.transform import rotate, AffineTransform
from skimage.util import random_noise
from skimage.filters import gaussian
from scipy import ndimage

# %%
def plot_side_by_side(img1, img2, title1, title2, cmap = None):
    fig = plt.figure(tight_layout='auto', figsize=(10, 7))
    fig.add_subplot(221)
    plt.title(title1)
    plt.imshow(img)

    fig.add_subplot(222)
    plt.title(title2)
    plt.imshow(img2, cmap = None)
    return fig

# %%
# load Image
# dividing by 255 to scale intensity values between 0,1
img = imread(R'''C:\Users\EKHAETQ.ERICSSON\Downloads\deeplearning competition\data_clean\train\iv\add8501a-ce5d-11eb-b317-38f9d35ea60f.png''') / 255

# %%
# plot original Image
plt.imshow(img)
plt.show()

# %%
# image rotation using skimage.transformation.rotate
rotate30 = rotate(img, angle=30)
rotate45 = rotate(img, angle=45)
rotate60 = rotate(img, angle=60)
rotate90 = rotate(img, angle=90)

fig = plt.figure(tight_layout='auto', figsize=(10, 7))

fig.add_subplot(221)
plt.title('Rotate 30')
plt.imshow(rotate30)

fig.add_subplot(222)
plt.title('Rotate 45')
plt.imshow(rotate45)

fig.add_subplot(223)
plt.title('Rotate 60')
plt.imshow(rotate60)

fig.add_subplot(224)
plt.title('Rotate 90')
plt.imshow(rotate90)

plt.show()

# %%
# image shearing using sklearn.transform.AffineTransform
# try out with differnt values of shear 
tf = AffineTransform(shear=-0.2)
sheared = transform.warp(img, tf, order=1, preserve_range=True, mode='wrap')

sheared_fig = plot_side_by_side(img, sheared, 'Original', 'Sheared')

# %%
# Image rescaling with sklearn.transform.rescale
rescaled = transform.rescale(img, 1.1)

rescaled_fig = plot_side_by_side(img, rescaled, 'Original', 'Rescaled')
plt.show()

# %%
print('Original Shape: ',img.shape)
print('Rescaled Shape: ',rescaled.shape)
# Out:
# Original Shape:  (313, 258)
# Rescaled Shape:  (344, 284)

# %%
# flip up-down using np.flipud
up_down = np.flipud(img)

fig_updown = plot_side_by_side(img, up_down, 'Original', 'Up-Down')
plt.show()

# %%
# flip up-down using np.flipud

left_right = np.fliplr(img)

fig_lr = plot_side_by_side(img, left_right, 'Original', 'Up-Right')
plt.show()

# %%
# Apply Random Noise to image using skimage.utils.random_noise
noised = random_noise(img, var=0.1**2)

fig_noised = plot_side_by_side(img, noised, 'Original', 'Noised')
plt.show()

# %%
# Increasing the brighness of the Image
# Note: Here we add 100/255 since we scaled Intensity values of Image when loading (by dividing it 255)
highB = img + (100/255)

fig_highB = plot_side_by_side(img, highB, 'Original', 'highB')
plt.show()

# %%
# Increasing the contrast of the Image
# Note: Here we add 100/255 since we scaled Intensity values of Image when loading (by dividing it 255)
highC = img * 1.5

fig_highB = plot_side_by_side(img, highC, 'Original', 'highC')
plt.show()

# %% [markdown]
# ### Code to generate on Dataset

# %%
import glob
i = 1
for name in glob.glob(r'''C:\Users\EKHAETQ.ERICSSON\Downloads\deeplearning competition\data_clean\train\iv\*.png'''):
    file_name = ((name.split("\\")[-1]).split(".png")[0])
    
    # Rotating
    rotate30 = rotate(img, angle=30)
    plt.imsave(r'''C:\Users\EKHAETQ.ERICSSON\Downloads\deeplearning competition\data_clean\train\x\\''' + str(file_name) + "_r30 " + '''.png''', rotate30, cmap = plt.cm.gray)
    
    rotate45 = rotate(img, angle=45)
    plt.imsave(r'''C:\Users\EKHAETQ.ERICSSON\Downloads\deeplearning competition\data_clean\train\x\\''' + str(file_name) + "_r45" + '''.png''', rotate45, cmap = plt.cm.gray)
    
    # Shearing
    tf = AffineTransform(shear=-0.4)
    sheared = transform.warp(img, tf, order=1, preserve_range=True, mode='wrap')
    plt.imsave(r'''C:\Users\EKHAETQ.ERICSSON\Downloads\deeplearning competition\data_clean\train\x\\''' + str(file_name)  + "_affine" + '''.png''', sheared, cmap = plt.cm.gray)

    tf = AffineTransform(shear=-0.3)
    sheared = transform.warp(img, tf, order=1, preserve_range=True, mode='wrap')
    plt.imsave(r'''C:\Users\EKHAETQ.ERICSSON\Downloads\deeplearning competition\data_clean\train\x\\''' + str(file_name)  + "_affine3" + '''.png''', sheared, cmap = plt.cm.gray)

    tf = AffineTransform(shear=-0.5)
    sheared = transform.warp(img, tf, order=1, preserve_range=True, mode='wrap')
    plt.imsave(r'''C:\Users\EKHAETQ.ERICSSON\Downloads\deeplearning competition\data_clean\train\v\\''' + str(file_name)  + "_affine5" + '''.png''', sheared, cmap = plt.cm.gray)
    
    # Flipping
    up_down = np.flipud(img)
#     fig_updown = plot_side_by_side(img, up_down, 'Original', 'Up-Down')
    plt.imsave(r'''C:\Users\EKHAETQ.ERICSSON\Downloads\deeplearning competition\data_clean\train\x\\''' + str(file_name) + "_upDown" + '''.png''', up_down, cmap = plt.cm.gray)

    left_right = np.fliplr(img)
#     fig_lr = plot_side_by_side(img, left_right, 'Original', 'Up-Right')
    plt.imsave(r'''C:\Users\EKHAETQ.ERICSSON\Downloads\deeplearning competition\data_clean\train\vi\\''' + str(file_name) + "upRight" + '''.png''', left_right, cmap = plt.cm.gray)
